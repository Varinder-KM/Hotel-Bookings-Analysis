# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hotel booking analysis involves analyzing data related to hotel bookings to gain insights and make informed decisions.
#
# Some of the key data points that can be analyzed include booking patterns (such as time of year, length of stay, and booking channel), customer demographics (such as age, gender, and location), and customer behavior (such as cancellation rates and on-site spending).
#
# By analyzing this data, hotel managers can make more informed decisions about pricing, marketing strategies, and operational improvements. For example, they may identify patterns in booking behavior that suggest the need to adjust room rates during certain times of year or optimize their online booking process to increase conversion rates.
#
# Overall, hotel booking analysis can help hotels better understand their customers and improve their business operations to increase revenue and customer satisfaction.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link :- https://github.com/Varinder-KM/Hotel-Bookings-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem statement for hotel bookings analysis is how to use data analysis techniques to gain insights into customer behavior and preferences, such as booking patterns, customer demographics, and spending behavior. By analyzing this data, hotels can make more informed decisions about pricing, marketing, and operations to improve revenue and customer satisfaction.
#
# **Some specific questions that hotel booking analysis can help answer include:**
#
# * What are the most popular booking channels among customers?
# * What are the peak booking times throughout the year?
# * What types of customers are most likely to cancel their bookings?
# * What factors influence customer spending behavior during their stay?
# * How can hotels optimize their pricing strategy to increase revenue while remaining competitive in the market?
#
# Answering these questions through data analysis can help hotels better understand their customers, improve their marketing and pricing strategies, and ultimately increase revenue and customer satisfaction.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# the business objectives of hotel bookings analysis may include:
#
# 1. **Optimizing pricing strategy:** Analyzing customer booking patterns and spending behavior can help hotels identify optimal pricing strategies that maximize revenue while remaining competitive in the market.
#
# 2. **Improving marketing effectiveness:** Understanding customer demographics and booking channels can help hotels target their marketing efforts more effectively and reach the right customers with the right message.
#
# 3. **Enhancing operational efficiency:** Analyzing booking patterns and cancellations can help hotels optimize staffing levels and room availability, reducing costs and improving the customer experience.
#
# 4. **Increasing customer satisfaction:** By understanding customer preferences and behavior, hotels can tailor their offerings and services to better meet customer needs, leading to higher satisfaction and loyalty.
#
# Overall, the business objective of hotel bookings analysis is to use data-driven insights to make informed decisions that improve the bottom line and enhance the customer experience.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

import time as datetime

sns.set()
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',177)

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
dataset = pd.read_csv('/content/drive/MyDrive/Almabetter/Module 1 - Python For Data Science/Capstone Project/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Number of Rows in Dataset : ',dataset.shape[0])
print('Number of Columns in Dataset : ', dataset.shape[1])
# Out:
# Number of Rows in Dataset :  119390
# Number of Columns in Dataset :  32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dataset.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
msno.matrix(dataset,sparkline=False, figsize=(15,5), fontsize=12, color=(0.27, 0.52, 1.0))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   All the variables are in proper datatype except 'resevation_status_date'
# *   Dataet contains 31994 duplicate values.
# *   chlildren, country, Agent and company variables contains null values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Almost in all the Numerical columns datas are close to normally distributed.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
def unique_values(feturs):
  for col in feturs:
    print('{} number of unique values : {}'.format(col, len(dataset[col].unique())))

# %%
features = dataset.describe(include='all').columns
unique_values(features)
# Out:
# hotel number of unique values : 2
# is_canceled number of unique values : 2
# lead_time number of unique values : 479
# arrival_date_year number of unique values : 3
# arrival_date_month number of unique values : 12
# arrival_date_week_number number of unique values : 53
# arrival_date_day_of_month number of unique values : 31
# stays_in_weekend_nights number of unique values : 17
# stays_in_week_nights number of unique values : 35
# adults number of unique values : 14
# children number of unique values : 6
# babies number of unique values : 5
# meal number of unique values : 5
# country number of unique values : 178
# market_segment number of unique values : 8
# distribution_channel number of unique values : 5
# is_repeated_guest number of unique values : 2
# previous_cancellations number of unique values : 15
# previous_bookings_not_canceled number of unique values : 73
# reserved_room_type number of unique values : 10
# assigned_room_type number of unique values : 12
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ##### Dealing with Null Values

# %%
print('{}      {} '.format('Feature', 'null_values(%)'))
print(' ')
print('{}       {}'.format('children', round((dataset['children'].isna().sum()/len(dataset))*100, 3) ))
print('{}        {}'.format('country', round((dataset['country'].isna().sum()/len(dataset))*100, 3) ))
print('{}          {}'.format('agent', round((dataset['agent'].isna().sum()/len(dataset))*100, 3) ))
print('{}        {}'.format('company', round((dataset['company'].isna().sum()/len(dataset))*100, 3) ))
# Out:
# Feature      null_values(%)
#
# children       0.003
# country        0.409
# agent          13.686
# company        94.307

# %% [markdown]
# Over 50% Missig values
#
# We can remove those columns that have more then 50% null values.
# 'company' has null values more then 50%, therefore we can drop company column

# %%
dataset.drop(['company'],  axis=1,  inplace=True)

# %% [markdown]
# ###### children
#
# children column has 4 null observations. However, these nulls may be attributed to customers that have no child with them. If this assumption proves to be true, we can impute these nulls with '0' as the customers do not have a child with them.

# %%
dataset['children'] = dataset['children'].fillna(0)

# %% [markdown]
# ###### country
#
# country column has 488 null observations. we can impute these null values with most frequent value.

# %%
dataset['country'] = dataset['country'].fillna(dataset['country'].mode())

# %% [markdown]
# ###### agent
#
# agent column has 16340 null observations. However, these nulls may be attributed to customers done their booking without the help of any agent. If this assumption proves to be true, we can impute these nulls with '0' as the customers book hotel without any agent.

# %%
dataset['agent'] = dataset['agent'].fillna(0)

# %% [markdown]
# ##### Making 'reservation_status_date' column dtype to Date format

# %%
dataset['reservation_status_date'] = pd.to_datetime(dataset['reservation_status_date'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *   Manipulation I done:-
#       1. Handling Missing Data
#       2. Data type changing
#
#
# *   Insights I get :-
#
#       1. In 94% data company name was not provided, therefore it seems that most of the hotel are indipendent or small-town hotel.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate Visualization**

# %% [markdown]
# #### Numerical Features (Continuous)

# %%
#Numerical Features
num_features = dataset.describe().columns

# %%
#continuous variables
counti_featrs = [col for col in num_features if len(dataset[col].unique()) > 20]
counti_featrs
# Out:
# ['lead_time',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_week_nights',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'days_in_waiting_list',
#  'adr']

# %%
for col in counti_featrs:
  fig, (ax1, ax2) = plt.subplots(1,2, figsize=(16, 6))

  #density plot
  sns.distplot(dataset[col], ax=ax1)
  #box plot
  ax2.boxplot(dataset[col])
  ax2.set_xlabel(col)
  
plt.ioff()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# *   **Distplot :-** A dist plot provides an intuitive and easy-to-understand way to visualize the distribution of the data. It also allow viewers to identify the skewnesss and kurtosis of the data, which are measures of the degree to which the data deviates from a normal distribution.
# *   **Boxplot :-** Boxplots display important statistical values such as the median, quartiles, and outliers, making it easy to identify the range of the data. It is resistant to outliers, which are extreme values that can skew the results of other types of charts, making them a useful tool for analyzing datasets that include unusual values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Following insights i found :
#
# 1.   Most of the customers lead time is 0-50 days
# 2.   Most of the customers stays for 0-8 nights in week

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Numerical (Discrete)

# %%
#Discrete Variables
dist_variables = [col for col in num_features if len(dataset[col].unique()) <= 20]
dist_variables
# Out:
# ['is_canceled',
#  'arrival_date_year',
#  'stays_in_weekend_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
for col in dist_variables:
  plt.figure(figsize=(8, 5))
  sns.countplot(x = col,
            data = dataset,
            order = dataset[col].value_counts().index)
plt.show()
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar chart are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   cancelation rate is more then successfull booking rate
# 2.   booking rate increased in 2016 and after 2016 it start decreasing.
# 3.   There is not more then 4 stays_in_weekend_nights rate in customers.
# 4.   In most of the booking adults count is two. those two adults mai be couples.
# 5.   In very few bookings children or babies are present.
# 6.   Repeated Guest Rate is very less.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. It seems that most of the gusts are couples.So, are there should special offers and facilities for couples.
# 2. Study the market strategies was adopted in 2016.

# %% [markdown]
# ### Categorical Variables

# %%
catg_variables = dataset.describe(include='object').columns
catg_variables
# Out:
# Index(['hotel', 'arrival_date_month', 'meal', 'country', 'market_segment',
#        'distribution_channel', 'reserved_room_type', 'assigned_room_type',
#        'deposit_type', 'customer_type', 'reservation_status'],
#       dtype='object')

# %%
for col in catg_variables:
  plt.figure(figsize=(12, 5))
  sns.countplot(x = col,
              data = dataset,
              order = dataset[col].value_counts().index)
plt.show()
plt.ioff()

# %%
country = dataset['country'].value_counts().reset_index()
country.rename(columns={'index':'country', 'country':'count'})
# Out:
#     country  count
# 0       PRT  48590
# 1       GBR  12129
# 2       FRA  10415
# 3       ESP   8568
# 4       DEU   7287
# 5       ITA   3766
# 6       IRL   3375
# 7       BEL   2342
# 8       BRA   2224
# 9       NLD   2104
# 10      USA   2097
# 11      CHE   1730
# 12       CN   1279
# 13      AUT   1263
# 14      SWE   1024
# 15      CHN    999
# 16      POL    919
# 17      ISR    669
# 18      RUS    632
# 19      NOR    607
# 20      ROU    500
# 21      FIN    447
# 22      DNK    435
# 23      AUS    426
# 24      AGO    362
# 25      LUX    287
# 26      MAR    259
# 27      TUR    248
# 28      HUN    230
# 29      ARG    214
# 30      JPN    197
# 31      CZE    171
# 32      IND    152
# 33      KOR    133
# 34      GRC    128
# 35      DZA    103
# 36      SRB    101
# 37      HRV    100
# 38      MEX     85
# 39      EST     83
# 40      IRN     83
# 41      LTU     81
# 42      ZAF     80
# 43      BGR     75
# 44      NZL     74
# 45      COL     71
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Most of the booking are of city hotels.
# 2.   Gust arrivence are more in Summers.
# 3.   BB is more likely opted meal.
# 4.   Most of the customer are comes from online TA/TO.
# 5.   most of the customers reserves Roome type 'A'
# 6.   most of the bookings are done without any deposit.
# 7.   most of the customers are Transient Type customer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Sence most of the customers are comes from online therefore we should start online advertisement of ower hotel.

# %% [markdown]
# ### **Bivariate Visualization (Numerical - Categorical)**

# %% [markdown]
# #### Hotel - is_canceled

# %%
# Chart - 3 visualization code
bv1 = dataset.groupby('hotel')['is_canceled'].sum()

fig, ax = plt.subplots(figsize=(8,7))
palette_color = sns.color_palette('pastel')
ax.pie(bv1.values, labels =bv1.index, colors=palette_color, autopct='%.0f%%')
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are particularly effective at displaying the relative size of different categories or segments within a dataset. They allow you to quickly and easily see how much of the total each category represents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Comparatively city hotels have more cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# study the things that are different between city hotel and resort hotel that increase the cancellation rate in city hotel as compaire to resort hotel.

# %% [markdown]
# #### hotel - lead_time

# %%
# visualization code
bv2 = dataset.groupby('hotel')['lead_time'].mean()
fig, ax = plt.subplots(figsize=(8, 6))
bv2.plot(kind='bar')
ax.set_ylabel('lead_time')
# Out:
# Text(0, 0.5, 'lead_time')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In both hotels lead_time is high.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# High lead_time means advanced bookings are made in those hotels.

# %% [markdown]
# #### hotel - stays_in_weekend_nights & staya_in_week_in_nights

# %%
# visualization code
bv3  = dataset.groupby('hotel')['stays_in_weekend_nights', 'stays_in_week_nights'].sum()

plt.rcParams["figure.figsize"] = [10, 8]
bv3.plot(kind='bar')
plt.ioff()
# Out:
# <ipython-input-30-39ef69ed11d0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv3  = dataset.groupby('hotel')['stays_in_weekend_nights', 'stays_in_week_nights'].sum()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In Both Hotels week_nights are more then weekend nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By insight we have to analyse the types of the customers in satys in week_nights and weekend_nights

# %% [markdown]
# #### hotel - adults, children, babies

# %%
# visualization code
bv4 = dataset.groupby('hotel')['adults', 'children', 'babies'].sum()

bv4.plot(kind='bar', subplots=True)
plt.ioff()
# Out:
# <ipython-input-31-bdaa25ed0ad0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv4 = dataset.groupby('hotel')['adults', 'children', 'babies'].sum()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Adult guests are more in city hotels.
# *   babies are more in resort hotel bookings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By insight we have to analyse the services of the resort hotel.

# %% [markdown]
# #### hotel - is_repeated_guest

# %%
# visualization code
bv5 = dataset.groupby('hotel')['is_repeated_guest'].mean()
fig, ax = plt.subplots(figsize=(8, 6))
bv2.plot(kind='barh')
ax.set_xlabel('is_repeated_guset')
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City hotel have slightly more repeated guest rate then resort hotel

# %% [markdown]
# #### hotel - agent

# %%
#visualization code
bv6 = dataset.groupby('hotel')['agent'].mean()
fig, ax = plt.subplots(figsize=(8, 6))
bv6.plot(kind='bar')
ax.set_ylabel('agent')
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# In Resort hotels most of the booking are done through agents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it seems that the booking proccess of Resort hotels is complecated or rooms in Resort hotels are in high demand.

# %% [markdown]
# #### hotel - days_in_waiting_list

# %%
# visualization code
bv6 = dataset.groupby('hotel')['days_in_waiting_list'].mean()
fig, ax = plt.subplots(figsize=(8, 6))
bv6.plot(kind='bar')
ax.set_ylabel('days_in_waiting_list')
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It seems that the booking process of the city hotel is slow and less facilitated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Make the booking process of the city hotel fast and add new booking facilities in the booking process of the city hotels

# %% [markdown]
# #### hotel - required_car_parking, total_of_special_req

# %%
# visualization code
bv7 = dataset.groupby('hotel')['required_car_parking_spaces', 'total_of_special_requests'].sum()
bv7.plot(kind='barh', subplots=True)
plt.ioff()
# Out:
# <ipython-input-35-2fd106645a03>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv7 = dataset.groupby('hotel')['required_car_parking_spaces', 'total_of_special_requests'].sum()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   city hotel have more parking spaces.
# *   resort hotels have more spacial requirements.

# %% [markdown]
# #### arrival_date_month - is_canceled

# %%
# visualization code
fig, ax = plt.subplots(figsize=(14, 6))
sns.barplot(x='arrival_date_month', y='is_canceled', data=dataset)
# Out:
# <AxesSubplot:xlabel='arrival_date_month', ylabel='is_canceled'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a more cancelation rate in April, May and June months

# %% [markdown]
# #### arrival_date_month - adults, children, babies

# %%
# visualization code
fig, ax = plt.subplots(1, 3, figsize=(24, 12))
bv9_adlt = dataset.groupby('arrival_date_month')['adults'].sum()
bv9_childs = dataset.groupby('arrival_date_month')['children'].sum()
bv9_babies = dataset.groupby('arrival_date_month')['babies'].sum()

palette_color = sns.color_palette('pastel')

ax[0].pie(bv9_adlt.values, labels =bv9_adlt.index, colors=palette_color, autopct='%.0f%%')
ax[0].set_title('arrival_date_month - adults')

ax[1].pie(bv9_childs.values, labels =bv9_childs.index, colors=palette_color, autopct='%.0f%%')
ax[1].set_title('arrival_date_month - children')

ax[2].pie(bv9_babies.values, labels =bv9_babies.index, colors=palette_color, autopct='%.0f%%')
ax[2].set_title('arrival_date_month - babies')
plt.ioff()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are particularly effective at displaying the relative size of different categories or segments within a dataset. They allow you to quickly and easily see how much of the total each category represents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It seems that most of the adult, children and babies guests are comes in summer months (April, May, June, July, August).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * give some special summer vacation offers.
# * give more advertisements in summers.

# %% [markdown]
# #### meal -  is_canceled

# %%
#visualization code
bv10 = dataset.groupby('meal')['is_canceled'].mean()
bv10.sort_values(ascending=False).plot(kind='bar')
plt.ylabel('is_canceled')
# Out:
# Text(0, 0.5, 'is_canceled')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# FB meal have high cancellation rate

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Try to change the meal type.

# %% [markdown]
# #### country -  is_canceled

# %%
#visualization code
bv11 = dataset.groupby('country')['is_canceled'].sum()
print(round((bv11.sort_values(ascending=False)/len(dataset))*100, 2))
# Out:
# country
# PRT    23.05
# GBR     2.05
# ESP     1.82
# FRA     1.62
# ITA     1.12
# DEU     1.02
# IRL     0.70
# BRA     0.70
# USA     0.42
# BEL     0.40
# CHN     0.39
# CHE     0.36
# NLD     0.32
# CN      0.21
# RUS     0.20
# AUT     0.19
# SWE     0.19
# POL     0.18
# AGO     0.17
# NOR     0.15
# ISR     0.14
# ROU     0.11
# MAR     0.09
# DNK     0.09
# LUX     0.09
# AUS     0.09
# TUR     0.09
# HUN     0.06
# FIN     0.06
# KOR     0.05
# ARG     0.05
# ARE     0.04
# CZE     0.03
# IND     0.03
# GRC     0.03
# SAU     0.03
# ZAF     0.03
# JPN     0.02
# HKG     0.02
# PHL     0.02
# HRV     0.02
# IDN     0.02
# SVK     0.02
# COL     0.02
# IRN     0.02
# NGA     0.02
# DZA     0.02
# UKR     0.02
# MOZ     0.02
# TUN     0.02
# EST     0.02
# THA     0.02
# CHL     0.01
# SGP     0.01
# SVN     0.01
# MAC     0.01
# GEO     0.01
# TWN     0.01
# BGR     0.01
# VEN     0.01
# CPV     0.01
# GIB     0.01
# EGY     0.01
# CYP     0.01
# QAT     0.01
# MEX     0.01
# ...

# %% [markdown]
# #### market_segment - is_canceled, is_repeated_guest

# %%
# visualization code
bv12 = dataset.groupby('market_segment')['is_canceled', 'is_repeated_guest'].mean()
bv12.plot(kind='bar')
plt.ioff()
# Out:
# <ipython-input-40-cf58ce148dfc>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv12 = dataset.groupby('market_segment')['is_canceled', 'is_repeated_guest'].mean()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Complementary market sagement have comparatively less cancellation rate have comparatively high repetition rate.
# *   Group, Offline TA/TO and Online TA market sagement have comparatively high cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Identify why the market segment customers make their booking cancel

# %% [markdown]
# #### distribution_channel - is_canceled, is_repeated_guest

# %%
# visualization code
bv13 = dataset.groupby('distribution_channel')['is_canceled', 'is_repeated_guest'].mean()
bv13.plot(kind='bar')
plt.ioff()
# Out:
# <ipython-input-41-d04f2a7e0e92>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv13 = dataset.groupby('distribution_channel')['is_canceled', 'is_repeated_guest'].mean()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Corporate distribution_channel perform well as compaire other distribution_channels

# %% [markdown]
# #### customer_type - is_canceled, is_repeated_guest

# %%
# visualization code
bv14 = dataset.groupby('customer_type')['is_canceled', 'is_repeated_guest'].mean()
bv14.plot(kind='bar')
plt.ioff()
# Out:
# <ipython-input-42-21676f6c12d0>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   bv14 = dataset.groupby('customer_type')['is_canceled', 'is_repeated_guest'].mean()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Group type customers comparatively do less cancellation of their booking.

# %% [markdown]
# ### **Bivarient Visualization (Numerical - Numerical)**

# %% [markdown]
# #### is_canceled - days_in_waiting_list

# %%
# visualization code
bv15 = dataset.groupby('days_in_waiting_list')['is_canceled'].sum().reset_index()
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x='days_in_waiting_list', y='is_canceled', data=bv15)
# Out:
# <AxesSubplot:xlabel='days_in_waiting_list', ylabel='is_canceled'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Regplot is very use full in finding the type of relation between two varieble. it also represent the regression line.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no relation between cancellation and days_in_waiting_list variables

# %% [markdown]
# #### is_canceled - lead_time

# %%
# visualization code
bv16 = dataset.groupby('lead_time')['is_canceled'].sum().reset_index()
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x='lead_time', y='is_canceled', data=bv16)
# Out:
# <AxesSubplot:xlabel='lead_time', ylabel='is_canceled'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Regplot is very use full in finding the type of relation between two varieble. it also represent the regression line.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is a negative relation between is_cancelation and lead_time

# %% [markdown]
# ### **Bivarient Visualization (Categorical - Categorical)**

# %% [markdown]
# #### hotel-customer_type

# %%
# visualization code
bv17 = dataset[['hotel','customer_type']]
fig, ax = plt.subplots(figsize=(10, 8))
sns.countplot('customer_type', hue='hotel', data=bv17)
plt.ioff()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Transient customers type is comparatively more in both hotel type.

# %% [markdown]
# #### hotel-market_segment

# %%
# visualization code
bv18 = dataset[['hotel','market_segment']]
fig, ax = plt.subplots(figsize=(14, 8))
sns.countplot('market_segment', hue='hotel', data=bv18)
plt.ioff()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# #### hotel-distribution_channel

# %%
# visualization code
bv19 = dataset[['hotel','distribution_channel']]
fig, ax = plt.subplots(figsize=(10, 8))
sns.countplot('distribution_channel', hue='hotel', data=bv19)
plt.ioff()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are easy to understand and interpret, even for those who are not familiar with data analysis. Bar plots are particularly useful for representing categorical data or discrete data. It is also enable quick and easy comparisons between data sets, making it easy to see which values are higher or lower.

# %% [markdown]
# ### **Mutivariate Visualization**

# %% [markdown]
# #### Heat Map

# %%
# heat map visualization code
fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(dataset.corr(), vmin=-1, vmax=1,linewidth=0.5, annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are useful for exploring correlations between different variables. By using different colors to represent different values, it is easy to see how one variable relates to another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   weekend_nights and week_nights have some correlation
# *   previous_bookings_not_canceled and is_repeated_guest

# %% [markdown]
# #### Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(dataset)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pairplots are a useful tool for visualizing relationships between multiple variables. Some of the advantages of pairplots include:
#
# **Quick identification of correlations:** Pairplots allow for quick identification of correlations between variables. By displaying all pairwise scatter plots in a single figure, it is easy to see which variables are strongly correlated with each other.
#
# **Visualization of distribution:** Pairplots also provide a visualization of the distribution of each variable. This allows for a better understanding of the underlying data and can help identify potential issues with the data.
#
# **Identification of outliers:** Pairplots can also be used to identify outliers in the data. Outliers will often appear as data points that do not follow the general trend of the data.
#
# **Efficient data exploration:** Pairplots can be used to efficiently explore large data sets. By displaying all pairwise scatter plots in a single figure, it is easy to identify interesting relationships between variables.
#
# Communication: Pairplots are an effective way to communicate findings to others. The visual nature of the plot makes it easy for others to understand the relationship between the variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
